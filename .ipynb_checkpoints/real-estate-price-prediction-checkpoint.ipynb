# %% [markdown]
# ## Importing the Dependincies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics
from sklearn.metrics import r2_score

# %% [markdown]
# ## Read Data Set

# %%
df = pd.read_csv('realtor-data.csv')
df.head()
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
df.shape
# Out:
# (306000, 10)

# %%
df.describe().T
# Out:
#                count           mean           std    min        25%  \
# bed         250076.0       3.491347  2.449591e+00    1.0       2.00
# bath        251318.0       2.574726  2.568545e+00    1.0       2.00
# acre_lot    239877.0       9.732298  5.308272e+02    0.0       0.16
# zip_code    305803.0    2552.165724  1.629820e+03  601.0    1605.00
# house_size  252557.0    2225.678298  3.665834e+03  100.0    1192.00
# price       306000.0  768092.378265  1.297715e+06    1.0  249000.00
#
#                   50%        75%         max
# bed              3.00       4.00        99.0
# bath             2.00       3.00       198.0
# acre_lot         0.43       1.59    100000.0
# zip_code      2151.00    3052.00     99999.0
# house_size    1748.00    2628.00   1450112.0
# price       460000.00  799000.00  60000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306000 entries, 0 to 305999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          306000 non-null  object
#  1   bed             250076 non-null  float64
#  2   bath            251318 non-null  float64
#  3   acre_lot        239877 non-null  float64
#  4   city            305948 non-null  object
#  5   state           306000 non-null  object
#  6   zip_code        305803 non-null  float64
#  7   house_size      252557 non-null  float64
#  8   prev_sold_date  109589 non-null  object
#  9   price           306000 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 23.3+ MB

# %% [markdown]
# ## Deleting Duplicated Rows and Handling Null Values

# %%
df.duplicated().sum()
# Out:
# 278154

# %%
df.drop_duplicates(inplace=True)

# %%
print('Missing Values')
print(df.isnull().sum())
total_missing = df.isna().sum()*100/len(df)
print('Percentage Missing Value %')
total_missing
# Out:
# Missing Values
# status                0
# bed                6324
# bath               6247
# acre_lot           4387
# city                 16
# state                 0
# zip_code             28
# house_size         6168
# prev_sold_date    17952
# price                 0
# dtype: int64
# Percentage Missing Value %
# status             0.000000
# bed               22.710623
# bath              22.434102
# acre_lot          15.754507
# city               0.057459
# state              0.000000
# zip_code           0.100553
# house_size        22.150399
# prev_sold_date    64.468864
# price              0.000000
# dtype: float64

# %%
df['bed'].fillna(df['bed'].mode()[0], inplace=True)
df['bath'].fillna(df['bath'].mode()[0], inplace=True)
df['acre_lot'].fillna(df['acre_lot'].median(), inplace=True)
df['house_size'].fillna(df['house_size'].mode()[0], inplace=True)

df = df.dropna(subset=['zip_code','city'])
df = df.drop('prev_sold_date', axis=1)

# %%
print('Missing Values')
print(df.isnull().sum())
total_missing = df.isna().sum()*100/len(df)
print('Percentage Missing Value %')
total_missing
# Out:
# Missing Values
# status        0
# bed           0
# bath          0
# acre_lot      0
# city          0
# state         0
# zip_code      0
# house_size    0
# price         0
# dtype: int64
# Percentage Missing Value %
# status        0.0
# bed           0.0
# bath          0.0
# acre_lot      0.0
# city          0.0
# state         0.0
# zip_code      0.0
# house_size    0.0
# price         0.0
# dtype: float64

# %% [markdown]
# ## Feature Extraction

# %%
df['house_count_city'] = df.groupby('city')['city'].transform('count')
df['total_rooms'] = df['bath'] + df['bed']

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %%
correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.describe()
# Out:
#                 bed          bath       acre_lot      zip_code    house_size  \
# count  27817.000000  27817.000000   27817.000000  27817.000000  2.781700e+04
# mean       3.393680      2.455117      18.708230   3345.988856  2.051664e+03
# std        1.918604      1.919619    1051.451697   2531.165303  8.898654e+03
# min        1.000000      1.000000       0.000000    601.000000  1.000000e+02
# 25%        3.000000      2.000000       0.230000   1845.000000  1.200000e+03
# 50%        3.000000      2.000000       0.530000   2831.000000  1.440000e+03
# 75%        4.000000      3.000000       1.500000   4074.000000  2.324000e+03
# max       99.000000    198.000000  100000.000000  99999.000000  1.450112e+06
#
#               price  house_count_city   total_rooms
# count  2.781700e+04      27817.000000  27817.000000
# mean   6.990911e+05        133.772549      5.848797
# std    1.385125e+06        251.055306      3.549225
# min    1.000000e+00          1.000000      2.000000
# 25%    2.000000e+05         27.000000      5.000000
# 50%    3.850000e+05         57.000000      5.000000
# 75%    6.950000e+05        112.000000      6.000000
# max    6.000000e+07       1228.000000    297.000000

# %%
df.hist(bins=10, figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
columns_for_outliers = ['bed', 'bath', 'acre_lot', 'house_size','price']

plt.figure(figsize=(12, 6))    
for i, col in enumerate(columns_for_outliers):
    plt.subplot(2, 3, i+1)
    sns.boxplot(data=df, y=col)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Drop Outliers

# %%
def outlier_treatment(datacolumn):
    """function to Remove outlier"""
    datacolumn = sorted(datacolumn)
    Q1,Q3 = np.percentile(datacolumn,[40,60])
    IQR = Q3-Q1
    lower_range = Q1 - (1.5*IQR)
    upper_range = Q3 + (1.5*IQR)
    return lower_range,upper_range,IQR

# %%
def count_outliers(feature):
    l, u, IQR = outlier_treatment(df[feature])
    count = 0
    if IQR != 0:
        count += len(df[(df[feature] > u) | (df[feature] < l)])
    print("lower: ",l,"- upper: ", u)
    print("will be dropped: ",count)
    return count

# %%
def drop_outliers(feature):
    l,u, IQR = outlier_treatment(df[feature])
    if IQR!=0:
        df.drop(df[ (df[feature] > u) | (df[feature] < l)].index,inplace=True)

# %%
for column in columns_for_outliers:
    print(column)
    count_outliers(column)
# Out:
# bed
# lower:  3.0 - upper:  3.0
# will be dropped:  0
# bath
# lower:  2.0 - upper:  2.0
# will be dropped:  0
# acre_lot
# lower:  0.31 - upper:  0.79
# will be dropped:  18643
# house_size
# lower:  408.0 - upper:  2520.0
# will be dropped:  6015
# price
# lower:  31500.0 - upper:  747500.0
# will be dropped:  6629

# %%
drop_outliers("house_size")
drop_outliers("price")

# %%
df.shape
# Out:
# (15871, 11)

# %%
df.hist(bins=10, figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))    
for i, col in enumerate(columns_for_outliers):
    plt.subplot(2, 3, i+1)
    sns.boxplot(data=df, y=col)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
df.describe().T
# Out:
#                     count           mean            std      min        25%  \
# bed               15871.0       2.932770       0.889385      1.0       3.00
# bath              15871.0       1.940772       0.681390      1.0       2.00
# acre_lot          15871.0      13.542320     819.319985      0.0       0.23
# zip_code          15871.0    3525.433684    2597.206057    601.0    1606.00
# house_size        15871.0    1367.054880     422.935151    408.0    1170.00
# price             15871.0  284585.590448  144959.985336  57375.0  160000.00
# house_count_city  15871.0     101.698633     162.691378      1.0      27.00
# total_rooms       15871.0       4.873543       1.336304      2.0       4.00
#
#                         50%        75%       max
# bed                    3.00       3.00      20.0
# bath                   2.00       2.00      20.0
# acre_lot               0.53       1.43   99999.0
# zip_code            2905.00    5152.00   95000.0
# house_size          1200.00    1600.00    2520.0
# price             275000.00  398000.00  596000.0
# house_count_city      55.00     111.00    1228.0
# total_rooms            5.00       5.00      40.0

# %%
correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Label Encoding

# %%
le = LabelEncoder()
df['status'] = le.fit_transform(df['status'])
df['city'] = le.fit_transform(df['city'])
df['state'] = le.fit_transform(df['state'])

# %%
correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Splitting Data

# %%
X = df.drop('price', axis = 1)
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test  = scaler.transform(X_test)

# %% [markdown]
# ## Training Model

# %% [markdown]
# ## 1. Linear Regression

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
preds = reg.predict(X_test)

# %%
reg.score(X_train, y_train)
# Out:
# 0.2078639623082199

# %%
print('MAE:',metrics.mean_absolute_error(y_test, preds))
print('MSE:',metrics.mean_squared_error(y_test, preds))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, preds)))

print('Linear Regression Score: ',reg.score(X_test,y_test))
# Out:
# MAE: 105042.51722664347
# MSE: 16109234662.635149
# RMSE: 126922.15985648507
# Linear Regression Score:  0.2445825667548316

# %% [markdown]
# ## 2. Random Forest Regression

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
predictions = rf_regressor.predict(X_test)
y_pred = rf_regressor.predict(X_test)
rf_score = r2_score(y_test, y_pred)
print('R2 Score: ',r2_score(y_test, y_pred))
# Out:
# R2 Score:  0.6430284881178348

# %% [markdown]
# ## 3. Decision Tree Regression

# %% [markdown]
# ## 4. K-Nearest Neighbors (KNN)

# %%
knn = KNeighborsRegressor(n_neighbors=10)

knn.fit(X_train,y_train)
knn.predict(X_test)

knn_score =  knn.score(X_test,y_test)
print('KNN: ',knn_score)
# Out:
# KNN:  0.47016573481955237

# %% [markdown]
# ## 1. Artificial Neural Network (ANN)

# %% [markdown]
# ### Model Comparison

# %%
model_names = ['Linear Regression', 'KNN', 'Random Forest Regression']
scores = [reg.score(X_test,y_test), knn_score, rf_score]

plt.bar(model_names, scores)
plt.title('Comparison of the Model Scores')
plt.xlabel('Model')
plt.ylabel('Score')
plt.show()
